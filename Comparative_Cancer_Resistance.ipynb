# %%
print("Comparative Cancer Resistance Project")
print("Mohammed Elleithy")
# Out:
# Comparative Cancer Resistance Project
# Mohammed Elleithy

# %%
animals = [
    "Human",
    "Elephant",
    "Bowhead Whale",
    "Tardigrade"
]

print(animals)
# Out:
# ['Human', 'Elephant', 'Bowhead Whale', 'Tardigrade']

# %%
species = ["Human",
           "Elephant",
           "Bowhead Whale",
           "Tardigrade"]

lifespan = [80, 70, 200, 1]

print(species)
print(lifespan)
# Out:
# ['Human', 'Elephant', 'Bowhead Whale', 'Tardigrade']
# [80, 70, 200, 1]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Species": [
        "Human",
        "Elephant",
        "Bowhead Whale",
        "Tardigrade"
    ],

    "Lifespan_Years": [
        80,
        70,
        200,
        1
    ]
}

df = pd.DataFrame(data)

df
# Out:
#          Species  Lifespan_Years
# 0          Human              80
# 1       Elephant              70
# 2  Bowhead Whale             200
# 3     Tardigrade               1

# %%
plt.figure(figsize=(8,5))

plt.bar(
    df["Species"],
    df["Lifespan_Years"]
)

plt.title("Lifespan Across Species")

plt.ylabel("Years")

plt.show()

# %%
data = {

"Species":[
"Human",
"Elephant",
"Bowhead Whale",
"Tardigrade"
],

"Mechanism":[
"Standard TP53",
"Multiple TP53 copies",
"Enhanced DNA repair",
"Dsup DNA protection"
]

}

df = pd.DataFrame(data)

df
# Out:
#          Species             Mechanism
# 0          Human         Standard TP53
# 1       Elephant  Multiple TP53 copies
# 2  Bowhead Whale   Enhanced DNA repair
# 3     Tardigrade   Dsup DNA protection

# %% [markdown]
# # Observation
#
# Large and long-lived organisms do not always show higher cancer incidence.
#
# This phenomenon is known as Peto's Paradox.
#
# Elephants evolved multiple TP53 copies.
#
# Whales appear to possess enhanced DNA maintenance systems.
#
# Tardigrades possess Dsup protein which protects DNA against radiation damage.

# %%
species = [
    "Human",
    "Elephant"
]

tp53 = [
    2,
    40
]

plt.figure(figsize=(6,4))

plt.bar(
    species,
    tp53
)

plt.title("Approximate TP53 Copy Numbers")

plt.ylabel("Gene Copies")

plt.show()

# %% [markdown]
# # Future Research Questions
#
# Can comparative cancer resistance mechanisms inspire future therapies?
#
# Can machine learning identify shared protective pathways across species?
#
# Can immune surveillance mechanisms be compared across elephants, whales, humans, and other organisms?
#
# Can comparative genomics reveal new cancer protective targets?
